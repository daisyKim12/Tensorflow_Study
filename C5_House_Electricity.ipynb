# %% [markdown]
# <a href="https://colab.research.google.com/github/daisyKim12/Tensorflow_Study/blob/main/Lecture_C5_House_Electricity.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Category 5
#
# `Individual House Hold Electric Power Consumption Dataset`

# %% [markdown]
# The original 'Individual House Hold Electric Power Consumption Dataset'
# has Measurements of electric power consumption in one household with
# a one-minute sampling rate over a period of almost 4 years.
#
# Different electrical quantities and some sub-metering values are available.
#
# For the purpose of the examination we have provided a subset containing
# the data for the first 60 days in the dataset. We have also cleaned the
# dataset beforehand to remove missing values. The dataset is provided as a
# csv file in the project.
#
# The dataset has a total of 7 features ordered by time.
#
# Your neural network must have a **validation MAE of approximately 0.055** or less on the normalized validation dataset for top marks.

# %% [markdown]
# #Import

# %%
import urllib
import os
import zipfile
import pandas as pd

import tensorflow as tf
from tensorflow.keras.layers import Dense, Conv1D, LSTM, Bidirectional
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import ModelCheckpoint

# %%
def download_and_extract_data():
  url = 'https://storage.googleapis.com/download.tensorflow.org/data/certificate/household_power.zip'
  urllib.request.urlretrieve(url, 'household_power.zip')
  with zipfile.ZipFile('household_power.zip', 'r') as zip_ref:
    zip_ref.extractall()

# %%
download_and_extract_data()

# %%
df = pd.read_csv('household_power_consumption.csv', sep=',', infer_datetime_format=True, index_col='datetime', header=0)
df.head(10)
# Out:
#                      Global_active_power  Global_reactive_power  Voltage  \
# datetime
# 2006-12-16 17:24:00                4.216                  0.418   234.84
# 2006-12-16 17:25:00                5.360                  0.436   233.63
# 2006-12-16 17:26:00                5.374                  0.498   233.29
# 2006-12-16 17:27:00                5.388                  0.502   233.74
# 2006-12-16 17:28:00                3.666                  0.528   235.68
# 2006-12-16 17:29:00                3.520                  0.522   235.02
# 2006-12-16 17:30:00                3.702                  0.520   235.09
# 2006-12-16 17:31:00                3.700                  0.520   235.22
# 2006-12-16 17:32:00                3.668                  0.510   233.99
# 2006-12-16 17:33:00                3.662                  0.510   233.86
#
#                      Global_intensity  Sub_metering_1  Sub_metering_2  \
# datetime
# 2006-12-16 17:24:00              18.4             0.0             1.0
# 2006-12-16 17:25:00              23.0             0.0             1.0
# 2006-12-16 17:26:00              23.0             0.0             2.0
# 2006-12-16 17:27:00              23.0             0.0             1.0
# 2006-12-16 17:28:00              15.8             0.0             1.0
# 2006-12-16 17:29:00              15.0             0.0             2.0
# 2006-12-16 17:30:00              15.8             0.0             1.0
# 2006-12-16 17:31:00              15.8             0.0             1.0
# 2006-12-16 17:32:00              15.8             0.0             1.0
# 2006-12-16 17:33:00              15.8             0.0             2.0
#
#                      Sub_metering_3
# datetime
# 2006-12-16 17:24:00            17.0
# 2006-12-16 17:25:00            16.0
# 2006-12-16 17:26:00            17.0
# 2006-12-16 17:27:00            17.0
# 2006-12-16 17:28:00            17.0
# 2006-12-16 17:29:00            17.0
# 2006-12-16 17:30:00            17.0
# 2006-12-16 17:31:00            17.0
# 2006-12-16 17:32:00            17.0
# 2006-12-16 17:33:00            16.0

# %%
def normalize_series(data, min, max):
  data = data - min
  data = data / max
  return data

# %%
N_FEATURES = len(df.columns)
data = df.values
data = normalize_series(data, data.min(axis=0), data.max(axis=0))
data
# Out:
# array([[0.43377912, 0.47826087, 0.04036551, ..., 0.        , 0.01282051,
#         0.85      ],
#        [0.55716135, 0.49885584, 0.0355582 , ..., 0.        , 0.01282051,
#         0.8       ],
#        [0.55867127, 0.56979405, 0.03420739, ..., 0.        , 0.02564103,
#         0.85      ],
#        ...,
#        [0.03710095, 0.        , 0.05983313, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03559103, 0.        , 0.06515693, ..., 0.        , 0.        ,
#         0.        ],
#        [0.03774806, 0.        , 0.06730234, ..., 0.        , 0.01282051,
#         0.        ]])

# %%
pd.DataFrame(data).describe()
# Out:
#                   0             1             2             3             4  \
# count  86400.000000  86400.000000  86400.000000  86400.000000  86400.000000
# mean       0.156411      0.147141      0.064697      0.152278      0.016950
# std        0.144040      0.134578      0.013900      0.139343      0.086787
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.021786      0.000000      0.055344      0.024752      0.000000
# 50%        0.131795      0.132723      0.065713      0.123762      0.000000
# 75%        0.239431      0.224256      0.074652      0.227723      0.000000
# max        0.979077      1.000000      0.107350      0.980198      1.000000
#
#                   5             6
# count  86400.000000  86400.000000
# mean       0.024085      0.375711
# std        0.097022      0.433595
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      0.000000
# 75%        0.012821      0.850000
# max        1.000000      1.000000

# %%
split_time = int(len(data) * 0.8)

# %%
x_train = data[:split_time]
x_valid = data[split_time:]

# %%
def windowed_dataset(series, batch_size, n_past=24, n_future=24, shift=1):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(size=(n_past + n_future), shift = shift, drop_remainder = True)
    ds = ds.flat_map(lambda w: w.batch(n_past + n_future))
    ds = ds.shuffle(len(series))
    ds = ds.map(
        lambda w: (w[:n_past], w[n_past:])
    )
    return ds.batch(batch_size).prefetch(1)

# %%
BATCH_SIZE = 32
N_PAST = 24
N_FUTURE = 24
SHIFT = 1

# %%
train_set = windowed_dataset(series=x_train,
                           batch_size=BATCH_SIZE,
                           )
valid_set = windowed_dataset(series=x_valid,
                           batch_size=BATCH_SIZE,
                           )

# %% [markdown]
# #Model, Checkpoint, Compile, Fit, Load, Evaluate

# %%
model = Sequential([
    Conv1D(filters = 32, kernel_size = 3, padding = 'causal', activation = 'relu', input_shape = [N_PAST, 7]),
    Bidirectional(LSTM(32, return_sequences=True)),
    Bidirectional(LSTM(32, return_sequences=True)),
    Dense(32, activation='relu'),
    Dense(16, activation='relu'),
    Dense(8, activation='relu'),
    Dense(N_FEATURES),
])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 24, 32)            704
#
#  bidirectional (Bidirectiona  (None, 24, 64)           16640
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 24, 64)           24832
#  nal)
#
#  dense (Dense)               (None, 24, 32)            2080
#
#  dense_1 (Dense)             (None, 24, 16)            528
#
#  dense_2 (Dense)             (None, 24, 8)             136
#
#  dense_3 (Dense)             (None, 24, 7)             63
#
# =================================================================
# Total params: 44,983
# Trainable params: 44,983
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpoint_path='model/my_checkpoint.ckpt'

checkpoint = ModelCheckpoint(checkpoint_path,
                             save_weights_only=True,
                             save_best_only=True,
                             monitor='val_loss',
                             verbose=1,
                             )

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.0005)

model.compile(optimizer=optimizer, loss = 'mae', metrics=['mae'])

# %%
model.fit(train_set, validation_data = valid_set, epochs = 30, callbacks=[checkpoint])
# Out:
# Epoch 1/30
#    2159/Unknown - 56s 13ms/step - loss: 0.0646 - mae: 0.0646
# Epoch 1: val_loss improved from inf to 0.04423, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 68s 19ms/step - loss: 0.0646 - mae: 0.0646 - val_loss: 0.0442 - val_mae: 0.0442
# Epoch 2/30
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0433 - mae: 0.0433
# Epoch 2: val_loss improved from 0.04423 to 0.04212, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 52s 18ms/step - loss: 0.0433 - mae: 0.0433 - val_loss: 0.0421 - val_mae: 0.0421
# Epoch 3/30
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0417 - mae: 0.0417
# Epoch 3: val_loss improved from 0.04212 to 0.04128, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 46s 17ms/step - loss: 0.0417 - mae: 0.0417 - val_loss: 0.0413 - val_mae: 0.0413
# Epoch 4/30
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0409 - mae: 0.0409
# Epoch 4: val_loss improved from 0.04128 to 0.04056, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 43s 16ms/step - loss: 0.0409 - mae: 0.0409 - val_loss: 0.0406 - val_mae: 0.0406
# Epoch 5/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0406 - mae: 0.0406
# Epoch 5: val_loss improved from 0.04056 to 0.03994, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0406 - mae: 0.0406 - val_loss: 0.0399 - val_mae: 0.0399
# Epoch 6/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0403 - mae: 0.0403
# Epoch 6: val_loss did not improve from 0.03994
# 2159/2159 [==============================] - 52s 20ms/step - loss: 0.0403 - mae: 0.0403 - val_loss: 0.0400 - val_mae: 0.0400
# Epoch 7/30
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0401 - mae: 0.0401
# Epoch 7: val_loss improved from 0.03994 to 0.03992, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0401 - mae: 0.0401 - val_loss: 0.0399 - val_mae: 0.0399
# Epoch 8/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0398 - mae: 0.0398
# Epoch 8: val_loss improved from 0.03992 to 0.03966, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 50s 19ms/step - loss: 0.0398 - mae: 0.0398 - val_loss: 0.0397 - val_mae: 0.0397
# Epoch 9/30
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0395 - mae: 0.0395
# Epoch 9: val_loss did not improve from 0.03966
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0395 - mae: 0.0395 - val_loss: 0.0398 - val_mae: 0.0398
# Epoch 10/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0394 - mae: 0.0394
# Epoch 10: val_loss improved from 0.03966 to 0.03945, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 49s 18ms/step - loss: 0.0394 - mae: 0.0394 - val_loss: 0.0395 - val_mae: 0.0395
# Epoch 11/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0392 - mae: 0.0392
# Epoch 11: val_loss improved from 0.03945 to 0.03934, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0392 - mae: 0.0392 - val_loss: 0.0393 - val_mae: 0.0393
# Epoch 12/30
# 2156/2159 [============================>.] - ETA: 0s - loss: 0.0388 - mae: 0.0388
# Epoch 12: val_loss improved from 0.03934 to 0.03913, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 43s 16ms/step - loss: 0.0388 - mae: 0.0388 - val_loss: 0.0391 - val_mae: 0.0391
# Epoch 13/30
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0387 - mae: 0.0387
# Epoch 13: val_loss did not improve from 0.03913
# 2159/2159 [==============================] - 44s 16ms/step - loss: 0.0387 - mae: 0.0387 - val_loss: 0.0393 - val_mae: 0.0393
# Epoch 14/30
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0386 - mae: 0.0386
# Epoch 14: val_loss improved from 0.03913 to 0.03886, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 45s 17ms/step - loss: 0.0386 - mae: 0.0386 - val_loss: 0.0389 - val_mae: 0.0389
# Epoch 15/30
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0385 - mae: 0.0385
# Epoch 15: val_loss improved from 0.03886 to 0.03875, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 49s 19ms/step - loss: 0.0385 - mae: 0.0385 - val_loss: 0.0388 - val_mae: 0.0388
# Epoch 16/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0383 - mae: 0.0383
# Epoch 16: val_loss did not improve from 0.03875
# 2159/2159 [==============================] - 47s 18ms/step - loss: 0.0383 - mae: 0.0383 - val_loss: 0.0389 - val_mae: 0.0389
# Epoch 17/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0383 - mae: 0.0383
# Epoch 17: val_loss did not improve from 0.03875
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0383 - mae: 0.0383 - val_loss: 0.0391 - val_mae: 0.0391
# Epoch 18/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0380 - mae: 0.0380
# Epoch 18: val_loss improved from 0.03875 to 0.03874, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 43s 16ms/step - loss: 0.0380 - mae: 0.0380 - val_loss: 0.0387 - val_mae: 0.0387
# Epoch 19/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0380 - mae: 0.0380
# Epoch 19: val_loss did not improve from 0.03874
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0380 - mae: 0.0380 - val_loss: 0.0389 - val_mae: 0.0389
# Epoch 20/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0378 - mae: 0.0378
# Epoch 20: val_loss did not improve from 0.03874
# 2159/2159 [==============================] - 43s 16ms/step - loss: 0.0378 - mae: 0.0378 - val_loss: 0.0390 - val_mae: 0.0390
# Epoch 21/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0377 - mae: 0.0377
# Epoch 21: val_loss improved from 0.03874 to 0.03867, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 47s 18ms/step - loss: 0.0377 - mae: 0.0377 - val_loss: 0.0387 - val_mae: 0.0387
# Epoch 22/30
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0375 - mae: 0.0375
# Epoch 22: val_loss improved from 0.03867 to 0.03859, saving model to model/my_checkpoint.ckpt
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0375 - mae: 0.0375 - val_loss: 0.0386 - val_mae: 0.0386
# Epoch 23/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0381 - mae: 0.0381
# Epoch 23: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 42s 16ms/step - loss: 0.0381 - mae: 0.0381 - val_loss: 0.0388 - val_mae: 0.0388
# Epoch 24/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0374 - mae: 0.0374
# Epoch 24: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 42s 16ms/step - loss: 0.0374 - mae: 0.0374 - val_loss: 0.0393 - val_mae: 0.0393
# Epoch 25/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0376 - mae: 0.0376
# Epoch 25: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 48s 19ms/step - loss: 0.0376 - mae: 0.0376 - val_loss: 0.0391 - val_mae: 0.0391
# Epoch 26/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0372 - mae: 0.0372
# Epoch 26: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0372 - mae: 0.0372 - val_loss: 0.0388 - val_mae: 0.0388
# Epoch 27/30
# 2158/2159 [============================>.] - ETA: 0s - loss: 0.0370 - mae: 0.0370
# Epoch 27: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 48s 18ms/step - loss: 0.0370 - mae: 0.0370 - val_loss: 0.0388 - val_mae: 0.0388
# Epoch 28/30
# 2157/2159 [============================>.] - ETA: 0s - loss: 0.0369 - mae: 0.0369
# Epoch 28: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 47s 18ms/step - loss: 0.0369 - mae: 0.0369 - val_loss: 0.0389 - val_mae: 0.0389
# Epoch 29/30
# 2155/2159 [============================>.] - ETA: 0s - loss: 0.0368 - mae: 0.0368
# Epoch 29: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 44s 16ms/step - loss: 0.0368 - mae: 0.0368 - val_loss: 0.0392 - val_mae: 0.0392
# Epoch 30/30
# 2159/2159 [==============================] - ETA: 0s - loss: 0.0369 - mae: 0.0369
# Epoch 30: val_loss did not improve from 0.03859
# 2159/2159 [==============================] - 44s 16ms/step - loss: 0.0369 - mae: 0.0369 - val_loss: 0.0389 - val_mae: 0.0389

# %%
model.load_weights(checkpoint_path)

# %%
model.evaluate(valid_set)
# Out:
# 539/539 [==============================] - 7s 8ms/step - loss: 0.0386 - mae: 0.0386
# [0.03858674690127373, 0.03858671337366104]
